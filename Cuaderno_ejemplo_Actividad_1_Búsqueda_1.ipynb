# %% [markdown]
# <a href="https://colab.research.google.com/github/Rms78/RazonamientoAutomatico/blob/main/Cuaderno_ejemplo_Actividad_1_B%C3%BAsqueda_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Actividad :  Resolución de problema mediante búsqueda heurística

# %%
# !pip install simpleai flask pydot graphviz
# Out:
# Collecting simpleai
#   Downloading simpleai-0.8.3.tar.gz (94 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.4/94.4 kB 1.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: flask in /usr/local/lib/python3.10/dist-packages (2.2.5)
# Requirement already satisfied: pydot in /usr/local/lib/python3.10/dist-packages (1.4.2)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.10/dist-packages (0.20.1)
# Requirement already satisfied: Werkzeug>=2.2.2 in /usr/local/lib/python3.10/dist-packages (from flask) (3.0.1)
# Requirement already satisfied: Jinja2>=3.0 in /usr/local/lib/python3.10/dist-packages (from flask) (3.1.2)
# Requirement already satisfied: itsdangerous>=2.0 in /usr/local/lib/python3.10/dist-packages (from flask) (2.1.2)
# Requirement already satisfied: click>=8.0 in /usr/local/lib/python3.10/dist-packages (from flask) (8.1.7)
# Requirement already satisfied: pyparsing>=2.1.4 in /usr/local/lib/python3.10/dist-packages (from pydot) (3.1.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from Jinja2>=3.0->flask) (2.1.3)
# Building wheels for collected packages: simpleai
#   Building wheel for simpleai (setup.py) ... done
#   Created wheel for simpleai: filename=simpleai-0.8.3-py3-none-any.whl size=100984 sha256=75dd44a024120eb5b99fd186105c7495bc36f0bb7a5ccbf309053402b13f3a63
#   Stored in directory: /root/.cache/pip/wheels/91/0c/38/421d7910e7bc59b97fc54f490808bdb1097607d83d1a592865
# Successfully built simpleai
# Installing collected packages: simpleai
# Successfully installed simpleai-0.8.3

# %%
#!/usr/bin/env python
# coding: utf-8

# 2023 Modified by: Rafa Mata, Alejandro Cervantes
# Remember installing pyplot and flask if you want to use WebViewer

# NOTA: WebViewer sólo funcionará si ejecutáis en modo local

from __future__ import print_function

import math
from simpleai.search import SearchProblem, astar, breadth_first, depth_first
from simpleai.search.viewers import BaseViewer,ConsoleViewer,WebViewer

MAP = """
########
#    T #
# #### #
#   P# #
# ##   #
#      #
########
"""

"""MAP_MOD =
##############
#          P #
# ### ########
#            #
# #########  #
#         #  #
#        T   #
##############
"""
MAP = [list(x) for x in MAP.split("\n") if x]

COSTS = {
    "up": 1.0,
    "down": 1.0,
    "right": 1.0,
    "left": 1.0,
}


class GameWalkPuzzle(SearchProblem):

    def __init__(self, board):
        self.board = board
        self.goal = (0, 0)
        for y in range(len(self.board)):
            for x in range(len(self.board[y])):
                if self.board[y][x].lower() == "t":
                    self.initial = (x, y)
                elif self.board[y][x].lower() == "p":
                    self.goal = (x, y)

        super(GameWalkPuzzle, self).__init__(initial_state=self.initial)

    def actions(self, state):
        actions = []
        for action in list(COSTS.keys()):
            newx, newy = self.result(state, action)
            if self.board[newy][newx] != "#":
                actions.append(action)
        return actions

    def result(self, state, action):
        x, y = state

        if action.count("up"):
            y -= 1
        if action.count("down"):
            y += 1
        if action.count("left"):
            x -= 1
        if action.count("right"):
            x += 1

        new_state = (x, y)
        return new_state

    def is_goal(self, state):
        return state == self.goal

    def cost(self, state, action, state2):
        return COSTS[action]

    def heuristic(self, state):
        x, y = state
        gx, gy = self.goal
        """Manhattan"""
        return (abs(x - gx) + abs(y - gy))
        """ Euclidea
        return math.sqrt((x - gx) ** 2 + (y - gy) ** 2)
        return math.sqrt((x - gx) ** 2 + (y - gy) ** 2)"""

def searchInfo (problem,result,use_viewer):
    def getTotalCost (problem,result):
        originState = problem.initial_state
        totalCost = 0
        for action,endingState in result.path():
            if action is not None:
                totalCost += problem.cost(originState,action,endingState)
                originState = endingState
        return totalCost


    res = "Total length of solution: {0}\n".format(len(result.path()))
    res += "Total cost of solution: {0}\n".format(getTotalCost(problem,result))

    if use_viewer:
        stats = [{'name': stat.replace('_', ' '), 'value': value}
                         for stat, value in list(use_viewer.stats.items())]

        for s in stats:
            res+= '{0}: {1}\n'.format(s['name'],s['value'])
    return res


def resultado_experimento(problem,MAP,result,used_viewer):
    path = [x[1] for x in result.path()]

    for y in range(len(MAP)):
        for x in range(len(MAP[y])):
            if (x, y) == problem.initial:
                print("T", end='')
            elif (x, y) == problem.goal:
                print("P", end='')
            elif (x, y) in path:
                print("·", end='')
            else:
                print(MAP[y][x], end='')
        print()

    info=searchInfo(problem,result,used_viewer)
    print(info)

def main():
    problem = GameWalkPuzzle(MAP)
    used_viewer=BaseViewer()
    # Probad también ConsoleViewer para depurar
    # No podréis usar aquí WebViewer en Collab para ver los árboles

    # Mostramos tres experimentos
    print('Breadth First: ')
    result = breadth_first(problem, graph_search=True,viewer=used_viewer)
    resultado_experimento(problem,MAP,result,used_viewer)

    problem = GameWalkPuzzle(MAP)
    used_viewer=BaseViewer()
    print('Depth First: ')
    result = depth_first(problem, graph_search=True,viewer=used_viewer)
    resultado_experimento(problem,MAP,result,used_viewer)

    problem = GameWalkPuzzle(MAP)
    used_viewer=BaseViewer()
    print('Astar: ')
    result = astar(problem, graph_search=True,viewer=used_viewer)
    resultado_experimento(problem,MAP,result,used_viewer)

# %%
"""mAHATTAN"""
main()
# Out:
# Breadth First:
# ########
# #    T·#
# # ####·#
# #   P#·#
# # ##···#
# #      #
# ########
# Total length of solution: 8
# Total cost of solution: 7.0
# max fringe size: 4
# visited nodes: 17
# iterations: 17
#
# Depth First:
# ########
# #····T #
# #·#### #
# #···P# #
# # ##   #
# #      #
# ########
# Total length of solution: 10
# Total cost of solution: 9.0
# max fringe size: 3
# visited nodes: 10
# iterations: 10
#
# Astar:
# ########
# #    T·#
# # ####·#
# #   P#·#
# # ##···#
# #      #
# ########
# Total length of solution: 8
# Total cost of solution: 7.0
# max fringe size: 5
# visited nodes: 11
# iterations: 11

# %%
"""eUCLIDEAN"""
main()
# Out:
# Breadth First:
# ##############
# #    ······P #
# # ###·########
# #    ······· #
# # #########· #
# #         #· #
# #        T·· #
# ##############
# Total length of solution: 20
# Total cost of solution: 19.0
# max fringe size: 5
# visited nodes: 51
# iterations: 51
#
# Depth First:
# ##############
# #    ······P #
# # ###·########
# #·····       #
# #·#########  #
# #·        #  #
# #········T   #
# ##############
# Total length of solution: 24
# Total cost of solution: 23.0
# max fringe size: 14
# visited nodes: 41
# iterations: 41
#
# Astar:
# After each step, a prompt will be shown.
# On the prompt, you can just press Enter to continue to the next step.
# But you can also have this commands:
# (write the command you want to use and then press Enter)
# * h: get help.
# * g PATH_TO_PNG_IMAGE: create png with graph of the current state.
# * e: run non-interactively to the end of the algorithm.
# * s: show statistics of the execution (max fringe size, visited nodes).
# * q: quit program.
# EVENT: started
# Algorithm just started.
# >
# EVENT: new_iteration
# New iteration with 1 elements in the fringe:
# [Node <(9, 6)>]
# >
# EVENT: chosen_node
# Chosen node: Node <(9, 6)>
# Not goal
# >
# EVENT: expanded
# Expanded [Node <(9, 6)>]
# Successors: [[Node <(9, 5)>, Node <(10, 6)>, Node <(8, 6)>]]
# >
# EVENT: new_iteration
# New iteration with 3 elements in the fringe:
# [Node <(9, 5)>, Node <(10, 6)>, Node <(8, 6)>]
# >
# EVENT: chosen_node
# Chosen node: Node <(9, 5)>
# Not goal
# >
# EVENT: expanded
# Expanded [Node <(9, 5)>]
# Successors: [[Node <(9, 6)>, Node <(8, 5)>]]
# >
# EVENT: new_iteration
# New iteration with 3 elements in the fringe:
# [Node <(10, 6)>, Node <(8, 6)>, Node <(8, 5)>]
# >
# EVENT: chosen_node
# Chosen node: Node <(10, 6)>
# Not goal
# >
# EVENT: expanded
# Expanded [Node <(10, 6)>]
# Successors: [[Node <(11, 6)>, Node <(9, 6)>]]
# >
# EVENT: new_iteration
# New iteration with 3 elements in the fringe:
# [Node <(8, 6)>, Node <(8, 5)>, Node <(11, 6)>]
# >  e
# EVENT: chosen_node
# Chosen node: Node <(8, 6)>
# Not goal
# EVENT: expanded
# Expanded [Node <(8, 6)>]
# Successors: [[Node <(8, 5)>, Node <(9, 6)>, Node <(7, 6)>]]
# EVENT: new_iteration
# New iteration with 3 elements in the fringe:
# [Node <(8, 5)>, Node <(11, 6)>, Node <(7, 6)>]
# EVENT: chosen_node
# Chosen node: Node <(8, 5)>
# Not goal
# EVENT: expanded
# Expanded [Node <(8, 5)>]
# Successors: [[Node <(8, 6)>, Node <(9, 5)>, Node <(7, 5)>]]
# EVENT: new_iteration
# New iteration with 3 elements in the fringe:
# [Node <(11, 6)>, Node <(7, 6)>, Node <(7, 5)>]
# EVENT: chosen_node
# Chosen node: Node <(11, 6)>
# Not goal
# EVENT: expanded
# Expanded [Node <(11, 6)>]
# Successors: [[Node <(11, 5)>, Node <(12, 6)>, Node <(10, 6)>]]
# EVENT: new_iteration
# New iteration with 4 elements in the fringe:
# [Node <(11, 5)>, Node <(12, 6)>, Node <(7, 6)>, Node <(7, 5)>]
# EVENT: chosen_node
# Chosen node: Node <(11, 5)>
# Not goal
# EVENT: expanded
# Expanded [Node <(11, 5)>]
# Successors: [[Node <(11, 4)>, Node <(11, 6)>, Node <(12, 5)>]]
# EVENT: new_iteration
# New iteration with 5 elements in the fringe:
# [Node <(11, 4)>, Node <(12, 6)>, Node <(12, 5)>, Node <(7, 6)>, Node <(7, 5)>]
# EVENT: chosen_node
# Chosen node: Node <(11, 4)>
# Not goal
# EVENT: expanded
# Expanded [Node <(11, 4)>]
# Successors: [[Node <(11, 3)>, Node <(11, 5)>, Node <(12, 4)>]]
# EVENT: new_iteration
# New iteration with 6 elements in the fringe:
# [Node <(11, 3)>, Node <(12, 6)>, Node <(12, 5)>, Node <(12, 4)>, Node <(7, 6)>, Node <(7, 5)>]
# EVENT: chosen_node
# Chosen node: Node <(11, 3)>
# Not goal
# EVENT: expanded
# Expanded [Node <(11, 3)>]
# Successors: [[Node <(11, 4)>, Node <(12, 3)>, Node <(10, 3)>]]
# EVENT: new_iteration
# New iteration with 7 elements in the fringe:
# [Node <(12, 6)>, Node <(12, 5)>, Node <(12, 4)>, Node <(12, 3)>, Node <(10, 3)>, Node <(7, 6)>, Node <(7, 5)>]
# EVENT: chosen_node
# Chosen node: Node <(12, 6)>
# Not goal
# EVENT: expanded
# Expanded [Node <(12, 6)>]
# Successors: [[Node <(12, 5)>, Node <(11, 6)>]]
# EVENT: new_iteration
# New iteration with 6 elements in the fringe:
# [Node <(12, 5)>, Node <(12, 4)>, Node <(10, 3)>, Node <(12, 3)>, Node <(7, 6)>, Node <(7, 5)>]
# EVENT: chosen_node
# Chosen node: Node <(12, 5)>
# Not goal
# EVENT: expanded
# Expanded [Node <(12, 5)>]
# Successors: [[Node <(12, 4)>, Node <(12, 6)>, Node <(11, 5)>]]
# EVENT: new_iteration
# New iteration with 5 elements in the fringe:
# [Node <(12, 4)>, Node <(10, 3)>, Node <(12, 3)>, Node <(7, 6)>, Node <(7, 5)>]
# EVENT: chosen_node
# Chosen node: Node <(12, 4)>
# Not goal
# EVENT: expanded
# Expanded [Node <(12, 4)>]
# Successors: [[Node <(12, 3)>, Node <(12, 5)>, Node <(11, 4)>]]
# EVENT: new_iteration
# New iteration with 4 elements in the fringe:
# [Node <(12, 3)>, Node <(10, 3)>, Node <(7, 6)>, Node <(7, 5)>]
# EVENT: chosen_node
# Chosen node: Node <(12, 3)>
# Not goal
# EVENT: expanded
# Expanded [Node <(12, 3)>]
# Successors: [[Node <(12, 4)>, Node <(11, 3)>]]
# EVENT: new_iteration
# New iteration with 3 elements in the fringe:
# [Node <(10, 3)>, Node <(7, 6)>, Node <(7, 5)>]
# EVENT: chosen_node
# Chosen node: Node <(10, 3)>
# Not goal
# EVENT: expanded
# Expanded [Node <(10, 3)>]
# Successors: [[Node <(11, 3)>, Node <(9, 3)>]]
# EVENT: new_iteration
# New iteration with 3 elements in the fringe:
# [Node <(7, 6)>, Node <(7, 5)>, Node <(9, 3)>]
# EVENT: chosen_node
# Chosen node: Node <(7, 6)>
# Not goal
# EVENT: expanded
# Expanded [Node <(7, 6)>]
# Successors: [[Node <(7, 5)>, Node <(8, 6)>, Node <(6, 6)>]]
# EVENT: new_iteration
# New iteration with 3 elements in the fringe:
# [Node <(7, 5)>, Node <(9, 3)>, Node <(6, 6)>]
# EVENT: chosen_node
# Chosen node: Node <(7, 5)>
# Not goal
# EVENT: expanded
# Expanded [Node <(7, 5)>]
# Successors: [[Node <(7, 6)>, Node <(8, 5)>, Node <(6, 5)>]]
# EVENT: new_iteration
# New iteration with 3 elements in the fringe:
# [Node <(9, 3)>, Node <(6, 6)>, Node <(6, 5)>]
# EVENT: chosen_node
# Chosen node: Node <(9, 3)>
# Not goal
# EVENT: expanded
# Expanded [Node <(9, 3)>]
# Successors: [[Node <(10, 3)>, Node <(8, 3)>]]
# EVENT: new_iteration
# New iteration with 3 elements in the fringe:
# [Node <(6, 6)>, Node <(6, 5)>, Node <(8, 3)>]
# EVENT: chosen_node
# Chosen node: Node <(6, 6)>
# Not goal
# EVENT: expanded
# Expanded [Node <(6, 6)>]
# Successors: [[Node <(6, 5)>, Node <(7, 6)>, Node <(5, 6)>]]
# EVENT: new_iteration
# New iteration with 3 elements in the fringe:
# [Node <(6, 5)>, Node <(8, 3)>, Node <(5, 6)>]
# EVENT: chosen_node
# Chosen node: Node <(6, 5)>
# Not goal
# EVENT: expanded
# Expanded [Node <(6, 5)>]
# Successors: [[Node <(6, 6)>, Node <(7, 5)>, Node <(5, 5)>]]
# EVENT: new_iteration
# New iteration with 3 elements in the fringe:
# [Node <(8, 3)>, Node <(5, 6)>, Node <(5, 5)>]
# EVENT: chosen_node
# Chosen node: Node <(8, 3)>
# Not goal
# EVENT: expanded
# Expanded [Node <(8, 3)>]
# Successors: [[Node <(9, 3)>, Node <(7, 3)>]]
# EVENT: new_iteration
# New iteration with 3 elements in the fringe:
# [Node <(5, 6)>, Node <(5, 5)>, Node <(7, 3)>]
# EVENT: chosen_node
# Chosen node: Node <(5, 6)>
# Not goal
# EVENT: expanded
# Expanded [Node <(5, 6)>]
# Successors: [[Node <(5, 5)>, Node <(6, 6)>, Node <(4, 6)>]]
# EVENT: new_iteration
# New iteration with 3 elements in the fringe:
# [Node <(5, 5)>, Node <(7, 3)>, Node <(4, 6)>]
# EVENT: chosen_node
# Chosen node: Node <(5, 5)>
# Not goal
# EVENT: expanded
# Expanded [Node <(5, 5)>]
# Successors: [[Node <(5, 6)>, Node <(6, 5)>, Node <(4, 5)>]]
# EVENT: new_iteration
# New iteration with 3 elements in the fringe:
# [Node <(7, 3)>, Node <(4, 6)>, Node <(4, 5)>]
# EVENT: chosen_node
# Chosen node: Node <(7, 3)>
# Not goal
# EVENT: expanded
# Expanded [Node <(7, 3)>]
# Successors: [[Node <(8, 3)>, Node <(6, 3)>]]
# EVENT: new_iteration
# New iteration with 3 elements in the fringe:
# [Node <(4, 6)>, Node <(4, 5)>, Node <(6, 3)>]
# EVENT: chosen_node
# Chosen node: Node <(4, 6)>
# Not goal
# EVENT: expanded
# Expanded [Node <(4, 6)>]
# Successors: [[Node <(4, 5)>, Node <(5, 6)>, Node <(3, 6)>]]
# EVENT: new_iteration
# New iteration with 3 elements in the fringe:
# [Node <(4, 5)>, Node <(6, 3)>, Node <(3, 6)>]
# EVENT: chosen_node
# Chosen node: Node <(4, 5)>
# Not goal
# EVENT: expanded
# Expanded [Node <(4, 5)>]
# Successors: [[Node <(4, 6)>, Node <(5, 5)>, Node <(3, 5)>]]
# EVENT: new_iteration
# New iteration with 3 elements in the fringe:
# [Node <(6, 3)>, Node <(3, 6)>, Node <(3, 5)>]
# EVENT: chosen_node
# Chosen node: Node <(6, 3)>
# Not goal
# EVENT: expanded
# Expanded [Node <(6, 3)>]
# Successors: [[Node <(7, 3)>, Node <(5, 3)>]]
# EVENT: new_iteration
# New iteration with 3 elements in the fringe:
# [Node <(3, 6)>, Node <(3, 5)>, Node <(5, 3)>]
# EVENT: chosen_node
# Chosen node: Node <(3, 6)>
# Not goal
# EVENT: expanded
# Expanded [Node <(3, 6)>]
# Successors: [[Node <(3, 5)>, Node <(4, 6)>, Node <(2, 6)>]]
# EVENT: new_iteration
# New iteration with 3 elements in the fringe:
# [Node <(3, 5)>, Node <(2, 6)>, Node <(5, 3)>]
# EVENT: chosen_node
# Chosen node: Node <(3, 5)>
# Not goal
# EVENT: expanded
# Expanded [Node <(3, 5)>]
# Successors: [[Node <(3, 6)>, Node <(4, 5)>, Node <(2, 5)>]]
# EVENT: new_iteration
# New iteration with 3 elements in the fringe:
# [Node <(2, 6)>, Node <(5, 3)>, Node <(2, 5)>]
# EVENT: chosen_node
# Chosen node: Node <(2, 6)>
# Not goal
# EVENT: expanded
# Expanded [Node <(2, 6)>]
# Successors: [[Node <(2, 5)>, Node <(3, 6)>, Node <(1, 6)>]]
# EVENT: new_iteration
# New iteration with 3 elements in the fringe:
# [Node <(5, 3)>, Node <(2, 5)>, Node <(1, 6)>]
# EVENT: chosen_node
# Chosen node: Node <(5, 3)>
# Not goal
# EVENT: expanded
# Expanded [Node <(5, 3)>]
# Successors: [[Node <(5, 2)>, Node <(6, 3)>, Node <(4, 3)>]]
# EVENT: new_iteration
# New iteration with 4 elements in the fringe:
# [Node <(2, 5)>, Node <(5, 2)>, Node <(1, 6)>, Node <(4, 3)>]
# EVENT: chosen_node
# Chosen node: Node <(2, 5)>
# Not goal
# EVENT: expanded
# Expanded [Node <(2, 5)>]
# Successors: [[Node <(2, 6)>, Node <(3, 5)>, Node <(1, 5)>]]
# EVENT: new_iteration
# New iteration with 4 elements in the fringe:
# [Node <(5, 2)>, Node <(1, 6)>, Node <(4, 3)>, Node <(1, 5)>]
# EVENT: chosen_node
# Chosen node: Node <(5, 2)>
# Not goal
# EVENT: expanded
# Expanded [Node <(5, 2)>]
# Successors: [[Node <(5, 1)>, Node <(5, 3)>]]
# EVENT: new_iteration
# New iteration with 4 elements in the fringe:
# [Node <(5, 1)>, Node <(1, 6)>, Node <(4, 3)>, Node <(1, 5)>]
# EVENT: chosen_node
# Chosen node: Node <(5, 1)>
# Not goal
# EVENT: expanded
# Expanded [Node <(5, 1)>]
# Successors: [[Node <(5, 2)>, Node <(6, 1)>, Node <(4, 1)>]]
# EVENT: new_iteration
# New iteration with 5 elements in the fringe:
# [Node <(6, 1)>, Node <(1, 6)>, Node <(4, 3)>, Node <(1, 5)>, Node <(4, 1)>]
# EVENT: chosen_node
# Chosen node: Node <(6, 1)>
# Not goal
# EVENT: expanded
# Expanded [Node <(6, 1)>]
# Successors: [[Node <(7, 1)>, Node <(5, 1)>]]
# EVENT: new_iteration
# New iteration with 5 elements in the fringe:
# [Node <(7, 1)>, Node <(1, 6)>, Node <(4, 3)>, Node <(1, 5)>, Node <(4, 1)>]
# EVENT: chosen_node
# Chosen node: Node <(7, 1)>
# Not goal
# EVENT: expanded
# Expanded [Node <(7, 1)>]
# Successors: [[Node <(8, 1)>, Node <(6, 1)>]]
# EVENT: new_iteration
# New iteration with 5 elements in the fringe:
# [Node <(8, 1)>, Node <(1, 6)>, Node <(4, 3)>, Node <(1, 5)>, Node <(4, 1)>]
# EVENT: chosen_node
# Chosen node: Node <(8, 1)>
# Not goal
# EVENT: expanded
# Expanded [Node <(8, 1)>]
# Successors: [[Node <(9, 1)>, Node <(7, 1)>]]
# EVENT: new_iteration
# New iteration with 5 elements in the fringe:
# [Node <(9, 1)>, Node <(1, 6)>, Node <(4, 3)>, Node <(1, 5)>, Node <(4, 1)>]
# EVENT: chosen_node
# Chosen node: Node <(9, 1)>
# Not goal
# EVENT: expanded
# Expanded [Node <(9, 1)>]
# Successors: [[Node <(10, 1)>, Node <(8, 1)>]]
# EVENT: new_iteration
# New iteration with 5 elements in the fringe:
# [Node <(10, 1)>, Node <(1, 6)>, Node <(4, 3)>, Node <(1, 5)>, Node <(4, 1)>]
# EVENT: chosen_node
# Chosen node: Node <(10, 1)>
# Not goal
# EVENT: expanded
# Expanded [Node <(10, 1)>]
# Successors: [[Node <(11, 1)>, Node <(9, 1)>]]
# EVENT: new_iteration
# New iteration with 5 elements in the fringe:
# [Node <(11, 1)>, Node <(1, 6)>, Node <(4, 3)>, Node <(1, 5)>, Node <(4, 1)>]
# EVENT: chosen_node
# Chosen node: Node <(11, 1)>
# Is goal!
# EVENT: finished
# Finished algorithm returning Node <(11, 1)>.
# Solution type: goal found
# Path from initial to goal: [(None, (9, 6)), ('right', (10, 6)), ('right', (11, 6)), ('up', (11, 5)), ('up', (11, 4)), ('up', (11, 3)), ('left', (10, 3)), ('left', (9, 3)), ('left', (8, 3)), ('left', (7, 3)), ('left', (6, 3)), ('left', (5, 3)), ('up', (5, 2)), ('up', (5, 1)), ('right', (6, 1)), ('right', (7, 1)), ('right', (8, 1)), ('right', (9, 1)), ('right', (10, 1)), ('right', (11, 1))]
# ##############
# #    ······P #
# # ###·########
# #    ······· #
# # #########· #
# #         #· #
# #        T·· #
# ##############
# Total length of solution: 20
# Total cost of solution: 19.0
# max fringe size: 7
# visited nodes: 39
# iterations: 39
